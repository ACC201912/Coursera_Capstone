# %% [markdown]
# # Task_1

# %% [markdown]
# ## Task_1-1. install packages

# %%
conda install lxml html5lib beautifulsoup4
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - beautifulsoup4
#     - html5lib
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.9.0       |           py36_0         167 KB
#     ca-certificates-2020.1.1   |                0         125 KB
#     certifi-2020.4.5.1         |           py36_0         155 KB
#     libxslt-1.1.33             |       h7d1a2b0_0         426 KB
#     lxml-4.5.0                 |   py36hefd8a0e_0         1.4 MB
#     openssl-1.1.1g             |       h7b6447c_0         2.5 MB
#     soupsieve-2.0              |             py_0          33 KB
#     ------------------------------------------------------------
#                                            Total:         4.8 MB
#
# ...

# %% [markdown]
# ## Task_1-2. import library、obtain data

# %%
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
data = pd.read_html(url)

# %% [markdown]
# ## Task_1-3. clean data

# %%
df = data[0].dropna()
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %% [markdown]
# ## Task_1-4. extract data

# %%
df_2 = df.set_index('Postal Code', drop=False)

# %%
df_2
# Out:
#             Postal Code           Borough  \
# Postal Code
# M3A                 M3A        North York
# M4A                 M4A        North York
# M5A                 M5A  Downtown Toronto
# M6A                 M6A        North York
# M7A                 M7A  Downtown Toronto
# ...                 ...               ...
# M8X                 M8X         Etobicoke
# M4Y                 M4Y  Downtown Toronto
# M7Y                 M7Y      East Toronto
# M8Y                 M8Y         Etobicoke
# M8Z                 M8Z         Etobicoke
#
#                                                   Neighborhood
# Postal Code
# M3A                                                  Parkwoods
# M4A                                           Victoria Village
# M5A                                  Regent Park, Harbourfront
# M6A                           Lawrence Manor, Lawrence Heights
# M7A                Queen's Park, Ontario Provincial Government
# ...

# %%
df_3 = df_2.loc[['M5G','M2H','M4B','M1J','M4G','M4M','M1R','M9V','M9L','M5V','M1B','M5A'], 'Postal Code':'Neighborhood']

# %%
df_3
# Out:
#             Postal Code           Borough  \
# Postal Code
# M5G                 M5G  Downtown Toronto
# M2H                 M2H        North York
# M4B                 M4B         East York
# M1J                 M1J       Scarborough
# M4G                 M4G         East York
# M4M                 M4M      East Toronto
# M1R                 M1R       Scarborough
# M9V                 M9V         Etobicoke
# M9L                 M9L        North York
# M5V                 M5V  Downtown Toronto
# M1B                 M1B       Scarborough
# M5A                 M5A  Downtown Toronto
#
#                                                   Neighborhood
# Postal Code
# M5G                                         Central Bay Street
# M2H                                          Hillcrest Village
# M4B                            Parkview Hill, Woodbine Gardens
# M1J                                        Scarborough Village
# M4G                                                    Leaside
# ...

# %%
df_4 = df_3.reset_index(drop=True)

# %%
df_4
# Out:
#    Postal Code           Borough  \
# 0          M5G  Downtown Toronto
# 1          M2H        North York
# 2          M4B         East York
# 3          M1J       Scarborough
# 4          M4G         East York
# 5          M4M      East Toronto
# 6          M1R       Scarborough
# 7          M9V         Etobicoke
# 8          M9L        North York
# 9          M5V  Downtown Toronto
# 10         M1B       Scarborough
# 11         M5A  Downtown Toronto
#
#                                          Neighborhood
# 0                                  Central Bay Street
# 1                                   Hillcrest Village
# 2                     Parkview Hill, Woodbine Gardens
# 3                                 Scarborough Village
# 4                                             Leaside
# 5                                     Studio District
# 6                                   Wexford, Maryvale
# 7   South Steeles, Silverstone, Humbergate, Jamest...
# ...

# %% [markdown]
# ## Task_1-5. number of lines

# %%
df_4.shape
# Out:
# (12, 3)

# %% [markdown]
# # Task_2

# %% [markdown]
# ## Task_2-1. obtain data

# %%
df_5 = pd.read_csv('data/Geospatial_Coordinates.csv')
df_5
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# ## Task2-2. set data

# %%
df_6 = df_5.set_index('Postal Code')

# %%
df_6
# Out:
#               Latitude  Longitude
# Postal Code
# M1B          43.806686 -79.194353
# M1C          43.784535 -79.160497
# M1E          43.763573 -79.188711
# M1G          43.770992 -79.216917
# M1H          43.773136 -79.239476
# ...                ...        ...
# M9N          43.706876 -79.518188
# M9P          43.696319 -79.532242
# M9R          43.688905 -79.554724
# M9V          43.739416 -79.588437
# M9W          43.706748 -79.594054
#
# [103 rows x 2 columns]

# %%
df_7 = df_4.set_index('Postal Code', drop=False)

# %%
df_7
# Out:
#             Postal Code           Borough  \
# Postal Code
# M5G                 M5G  Downtown Toronto
# M2H                 M2H        North York
# M4B                 M4B         East York
# M1J                 M1J       Scarborough
# M4G                 M4G         East York
# M4M                 M4M      East Toronto
# M1R                 M1R       Scarborough
# M9V                 M9V         Etobicoke
# M9L                 M9L        North York
# M5V                 M5V  Downtown Toronto
# M1B                 M1B       Scarborough
# M5A                 M5A  Downtown Toronto
#
#                                                   Neighborhood
# Postal Code
# M5G                                         Central Bay Street
# M2H                                          Hillcrest Village
# M4B                            Parkview Hill, Woodbine Gardens
# M1J                                        Scarborough Village
# M4G                                                    Leaside
# ...

# %% [markdown]
# ## Task2-3. merge data

# %%
df_8 = df_7.join(df_6, how='inner')

# %%
df_8
# Out:
#             Postal Code           Borough  \
# Postal Code
# M5G                 M5G  Downtown Toronto
# M2H                 M2H        North York
# M4B                 M4B         East York
# M1J                 M1J       Scarborough
# M4G                 M4G         East York
# M4M                 M4M      East Toronto
# M1R                 M1R       Scarborough
# M9V                 M9V         Etobicoke
# M9L                 M9L        North York
# M5V                 M5V  Downtown Toronto
# M1B                 M1B       Scarborough
# M5A                 M5A  Downtown Toronto
#
#                                                   Neighborhood   Latitude  \
# Postal Code
# M5G                                         Central Bay Street  43.657952
# M2H                                          Hillcrest Village  43.803762
# M4B                            Parkview Hill, Woodbine Gardens  43.706397
# M1J                                        Scarborough Village  43.744734
# ...

# %%
df_9 = df_8.reset_index(drop=True)

# %%
df_9
# Out:
#    Postal Code           Borough  \
# 0          M5G  Downtown Toronto
# 1          M2H        North York
# 2          M4B         East York
# 3          M1J       Scarborough
# 4          M4G         East York
# 5          M4M      East Toronto
# 6          M1R       Scarborough
# 7          M9V         Etobicoke
# 8          M9L        North York
# 9          M5V  Downtown Toronto
# 10         M1B       Scarborough
# 11         M5A  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                                  Central Bay Street  43.657952 -79.387383
# 1                                   Hillcrest Village  43.803762 -79.363452
# 2                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 3                                 Scarborough Village  43.744734 -79.239476
# 4                                             Leaside  43.709060 -79.363452
# ...

# %% [markdown]
# # Task_3

# %% [markdown]
# ## Task_3-1. extract Toronto data

# %%
Toronto_data_1 = df_9[df_9['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
Toronto_data_1
# Out:
#   Postal Code           Borough  \
# 0         M5G  Downtown Toronto
# 1         M5V  Downtown Toronto
# 2         M5A  Downtown Toronto
#
#                                         Neighborhood   Latitude  Longitude
# 0                                 Central Bay Street  43.657952 -79.387383
# 1  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 2                          Regent Park, Harbourfront  43.654260 -79.360636

# %%
Toronto_data_2 = df_9[df_9['Borough'] == 'East Toronto'].reset_index(drop=True)
Toronto_data_2
# Out:
#   Postal Code       Borough     Neighborhood   Latitude  Longitude
# 0         M4M  East Toronto  Studio District  43.659526 -79.340923

# %%
Toronto_data_3 = pd.merge(Toronto_data_1,Toronto_data_2,how='outer')
Toronto_data_3
# Out:
#   Postal Code           Borough  \
# 0         M5G  Downtown Toronto
# 1         M5V  Downtown Toronto
# 2         M5A  Downtown Toronto
# 3         M4M      East Toronto
#
#                                         Neighborhood   Latitude  Longitude
# 0                                 Central Bay Street  43.657952 -79.387383
# 1  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 2                          Regent Park, Harbourfront  43.654260 -79.360636
# 3                                    Studio District  43.659526 -79.340923

# %% [markdown]
# ## Task_3-2. install packages

# %%
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# ## Task_3-3. create map

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(Toronto_data_3['Latitude'], Toronto_data_3['Longitude'], Toronto_data_3['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
