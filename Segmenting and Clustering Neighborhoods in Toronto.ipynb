# %% [markdown]
# <h1>TASK_1</h1>

# %% [markdown]
# <h2><u>1. installing packages</u></h2>

# %%
conda install lxml html5lib beautifulsoup4
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h2><u>2. importing library、obtaining data</u></h2>

# %%
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
data = pd.read_html(url)

# %% [markdown]
# <h2><u>3. cleaning data</u></h2>

# %%
df = data[0].dropna()
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %% [markdown]
# <h2><u>4. extracting data</u></h2>

# %%
df_2 = df.set_index('Postal Code', drop=False)

# %%
df_2
# Out:
#             Postal Code           Borough  \
# Postal Code
# M3A                 M3A        North York
# M4A                 M4A        North York
# M5A                 M5A  Downtown Toronto
# M6A                 M6A        North York
# M7A                 M7A  Downtown Toronto
# ...                 ...               ...
# M8X                 M8X         Etobicoke
# M4Y                 M4Y  Downtown Toronto
# M7Y                 M7Y      East Toronto
# M8Y                 M8Y         Etobicoke
# M8Z                 M8Z         Etobicoke
#
#                                                   Neighborhood
# Postal Code
# M3A                                                  Parkwoods
# M4A                                           Victoria Village
# M5A                                  Regent Park, Harbourfront
# M6A                           Lawrence Manor, Lawrence Heights
# M7A                Queen's Park, Ontario Provincial Government
# ...

# %%
df_3 = df_i.loc[['M5G','M2H','M4B','M1J','M4G','M4M','M1R','M9V','M9L','M5V','M1B','M5A'], 'Postal Code':'Neighborhood']

# %%
df_3
# Out:
#             Postal Code           Borough  \
# Postal Code
# M5G                 M5G  Downtown Toronto
# M2H                 M2H        North York
# M4B                 M4B         East York
# M1J                 M1J       Scarborough
# M4G                 M4G         East York
# M4M                 M4M      East Toronto
# M1R                 M1R       Scarborough
# M9V                 M9V         Etobicoke
# M9L                 M9L        North York
# M5V                 M5V  Downtown Toronto
# M1B                 M1B       Scarborough
# M5A                 M5A  Downtown Toronto
#
#                                                   Neighborhood
# Postal Code
# M5G                                         Central Bay Street
# M2H                                          Hillcrest Village
# M4B                            Parkview Hill, Woodbine Gardens
# M1J                                        Scarborough Village
# M4G                                                    Leaside
# ...

# %%
df_3.reset_index(drop=True)
# Out:
#    Postal Code           Borough  \
# 0          M5G  Downtown Toronto
# 1          M2H        North York
# 2          M4B         East York
# 3          M1J       Scarborough
# 4          M4G         East York
# 5          M4M      East Toronto
# 6          M1R       Scarborough
# 7          M9V         Etobicoke
# 8          M9L        North York
# 9          M5V  Downtown Toronto
# 10         M1B       Scarborough
# 11         M5A  Downtown Toronto
#
#                                          Neighborhood
# 0                                  Central Bay Street
# 1                                   Hillcrest Village
# 2                     Parkview Hill, Woodbine Gardens
# 3                                 Scarborough Village
# 4                                             Leaside
# 5                                     Studio District
# 6                                   Wexford, Maryvale
# 7   South Steeles, Silverstone, Humbergate, Jamest...
# ...

# %% [markdown]
# <h2><u>5. number of lines</u></h2>

# %%
df_3.shape
# Out:
# (12, 3)
